# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout, SimpleRNN, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
x = data.drop('is_safe', axis = 1)
y = data['is_safe']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)

print(y_train.shape)
print(x_train.shape)
# Out:
# (6394, 1)
# (6394, 16, 1)

# %%
model = Sequential()
model.add(SimpleRNN(128, input_shape=(16,1), activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))
# Out:
# 2022-10-24 21:53:07.854152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:07.855204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.007194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.008157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.009024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.009822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.011329: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-24 21:53:08.270293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.271164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.271920: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.272671: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.273450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:08.274214: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.665380: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.666349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.667196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.668017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.668792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.669520: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-10-24 21:53:11.673521: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 21:53:11.674357: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train,
          y_train,
          epochs= 50,
          validation_split=0.2)
# Out:
# 2022-10-24 21:53:12.272162: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 160/160 [==============================] - 7s 24ms/step - loss: 0.3879 - accuracy: 0.8656 - val_loss: 0.3258 - val_accuracy: 0.8718
# Epoch 2/50
# 160/160 [==============================] - 3s 19ms/step - loss: 0.2793 - accuracy: 0.8961 - val_loss: 0.2594 - val_accuracy: 0.9034
# Epoch 3/50
# 160/160 [==============================] - 3s 18ms/step - loss: 0.2594 - accuracy: 0.9042 - val_loss: 0.2832 - val_accuracy: 0.8999
# Epoch 4/50
# 160/160 [==============================] - 4s 28ms/step - loss: 0.2531 - accuracy: 0.9083 - val_loss: 0.2562 - val_accuracy: 0.9065
# Epoch 5/50
# 160/160 [==============================] - 5s 29ms/step - loss: 0.2490 - accuracy: 0.9092 - val_loss: 0.2557 - val_accuracy: 0.9060
# Epoch 6/50
# 160/160 [==============================] - 5s 30ms/step - loss: 0.2438 - accuracy: 0.9101 - val_loss: 0.2532 - val_accuracy: 0.9043
# Epoch 7/50
# 160/160 [==============================] - 4s 22ms/step - loss: 0.2442 - accuracy: 0.9101 - val_loss: 0.2674 - val_accuracy: 0.9019
# Epoch 8/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2425 - accuracy: 0.9120 - val_loss: 0.2479 - val_accuracy: 0.9084
# Epoch 9/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2408 - accuracy: 0.9120 - val_loss: 0.2451 - val_accuracy: 0.9086
# Epoch 10/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2436 - accuracy: 0.9096 - val_loss: 0.2476 - val_accuracy: 0.9052
# Epoch 11/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2341 - accuracy: 0.9126 - val_loss: 0.2456 - val_accuracy: 0.9071
# Epoch 12/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2335 - accuracy: 0.9124 - val_loss: 0.2404 - val_accuracy: 0.9116
# Epoch 13/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2324 - accuracy: 0.9147 - val_loss: 0.2525 - val_accuracy: 0.9098
# Epoch 14/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2294 - accuracy: 0.9152 - val_loss: 0.2431 - val_accuracy: 0.9090
# Epoch 15/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2301 - accuracy: 0.9143 - val_loss: 0.2473 - val_accuracy: 0.9119
# Epoch 16/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2272 - accuracy: 0.9164 - val_loss: 0.2412 - val_accuracy: 0.9094
# Epoch 17/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2321 - accuracy: 0.9144 - val_loss: 0.2384 - val_accuracy: 0.9111
# Epoch 18/50
# 160/160 [==============================] - 3s 22ms/step - loss: 0.2277 - accuracy: 0.9157 - val_loss: 0.2416 - val_accuracy: 0.9082
# Epoch 19/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2257 - accuracy: 0.9161 - val_loss: 0.2387 - val_accuracy: 0.9082
# Epoch 20/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2281 - accuracy: 0.9156 - val_loss: 0.2345 - val_accuracy: 0.9114
# Epoch 21/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2245 - accuracy: 0.9157 - val_loss: 0.2392 - val_accuracy: 0.9119
# Epoch 22/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2226 - accuracy: 0.9179 - val_loss: 0.2401 - val_accuracy: 0.9116
# Epoch 23/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2218 - accuracy: 0.9165 - val_loss: 0.2391 - val_accuracy: 0.9121
# Epoch 24/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2247 - accuracy: 0.9158 - val_loss: 0.2369 - val_accuracy: 0.9114
# Epoch 25/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2235 - accuracy: 0.9178 - val_loss: 0.2380 - val_accuracy: 0.9127
# Epoch 26/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2224 - accuracy: 0.9174 - val_loss: 0.2373 - val_accuracy: 0.9094
# Epoch 27/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2189 - accuracy: 0.9179 - val_loss: 0.2409 - val_accuracy: 0.9099
# Epoch 28/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2170 - accuracy: 0.9179 - val_loss: 0.2453 - val_accuracy: 0.9027
# Epoch 29/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2188 - accuracy: 0.9172 - val_loss: 0.2360 - val_accuracy: 0.9128
# Epoch 30/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2197 - accuracy: 0.9177 - val_loss: 0.2363 - val_accuracy: 0.9126
# Epoch 31/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.2221 - accuracy: 0.9171 - val_loss: 0.2359 - val_accuracy: 0.9113
# Epoch 32/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2169 - accuracy: 0.9184 - val_loss: 0.2349 - val_accuracy: 0.9124
# Epoch 33/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2165 - accuracy: 0.9189 - val_loss: 0.2332 - val_accuracy: 0.9127
# Epoch 34/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2144 - accuracy: 0.9177 - val_loss: 0.2389 - val_accuracy: 0.9096
# Epoch 35/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2144 - accuracy: 0.9188 - val_loss: 0.2485 - val_accuracy: 0.9123
# Epoch 36/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2165 - accuracy: 0.9183 - val_loss: 0.2384 - val_accuracy: 0.9084
# Epoch 37/50
# 160/160 [==============================] - 2s 16ms/step - loss: 0.2131 - accuracy: 0.9196 - val_loss: 0.2402 - val_accuracy: 0.9082
# Epoch 38/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2099 - accuracy: 0.9193 - val_loss: 0.2346 - val_accuracy: 0.9128
# Epoch 39/50
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2153 - accuracy: 0.9187 - val_loss: 0.2361 - val_accuracy: 0.9127
# Epoch 40/50
# 160/160 [==============================] - 3s 18ms/step - loss: 0.2111 - accuracy: 0.9191 - val_loss: 0.2415 - val_accuracy: 0.9079
# Epoch 41/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2116 - accuracy: 0.9199 - val_loss: 0.2382 - val_accuracy: 0.9132
# Epoch 42/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2094 - accuracy: 0.9198 - val_loss: 0.2358 - val_accuracy: 0.9129
# Epoch 43/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.2079 - accuracy: 0.9205 - val_loss: 0.2370 - val_accuracy: 0.9086
# Epoch 44/50
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2097 - accuracy: 0.9194 - val_loss: 0.2395 - val_accuracy: 0.9079
# Epoch 45/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2090 - accuracy: 0.9209 - val_loss: 0.2371 - val_accuracy: 0.9090
# Epoch 46/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2056 - accuracy: 0.9204 - val_loss: 0.2398 - val_accuracy: 0.9115
# Epoch 47/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2093 - accuracy: 0.9200 - val_loss: 0.2403 - val_accuracy: 0.9083
# Epoch 48/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2040 - accuracy: 0.9213 - val_loss: 0.2405 - val_accuracy: 0.9126
# Epoch 49/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.2057 - accuracy: 0.9207 - val_loss: 0.2587 - val_accuracy: 0.9132
# Epoch 50/50
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2042 - accuracy: 0.9211 - val_loss: 0.2463 - val_accuracy: 0.9113

# %%
evaluation=model.evaluate(x_test, y_test, verbose=1)
# Out:
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2285 - accuracy: 0.9111

# %%
pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
