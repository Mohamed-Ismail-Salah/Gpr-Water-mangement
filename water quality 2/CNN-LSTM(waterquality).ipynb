# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv1D, Flatten, MaxPool1D, BatchNormalization, Dropout, LSTM, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
X = data.drop('is_safe', axis = 1)
Y = data['is_safe']

x = data.drop('is_safe', axis = 1)
y = data['is_safe']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)

print(y_train.shape)
print(x_train.shape)
# Out:
# (6394, 1)
# (6394, 16, 1)

# %%
model = Sequential()
model.add(Conv1D(32, 3, padding="same",input_shape =(16,1), activation='relu'))
model.add(MaxPool1D(pool_size=(2)))  
model.add(Dropout(0.2))
model.add(Conv1D(32, 3, padding="same", activation='relu'))
model.add(MaxPool1D(pool_size=(2)))  
model.add(Dropout(0.2))
model.add(LSTM(128, input_shape=(16,1), activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(units=10))
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(x_train,
                    y_train,
                    batch_size = 500,
                    epochs= 100,
                    validation_split=0.2)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 68ms/step - loss: 0.6057 - accuracy: 0.8561 - val_loss: 0.4470 - val_accuracy: 0.8718
# Epoch 2/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.3992 - accuracy: 0.8880 - val_loss: 0.4042 - val_accuracy: 0.8718
# Epoch 3/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.3687 - accuracy: 0.8880 - val_loss: 0.3863 - val_accuracy: 0.8718
# Epoch 4/100
# 11/11 [==============================] - 0s 45ms/step - loss: 0.3585 - accuracy: 0.8880 - val_loss: 0.3799 - val_accuracy: 0.8718
# Epoch 5/100
# 11/11 [==============================] - 0s 39ms/step - loss: 0.3508 - accuracy: 0.8880 - val_loss: 0.3743 - val_accuracy: 0.8718
# Epoch 6/100
# 11/11 [==============================] - 0s 31ms/step - loss: 0.3468 - accuracy: 0.8880 - val_loss: 0.3705 - val_accuracy: 0.8718
# Epoch 7/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.3441 - accuracy: 0.8880 - val_loss: 0.3652 - val_accuracy: 0.8718
# Epoch 8/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.3422 - accuracy: 0.8880 - val_loss: 0.3648 - val_accuracy: 0.8718
# Epoch 9/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.3372 - accuracy: 0.8880 - val_loss: 0.3535 - val_accuracy: 0.8718
# Epoch 10/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.3306 - accuracy: 0.8880 - val_loss: 0.3446 - val_accuracy: 0.8718
# Epoch 11/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.3235 - accuracy: 0.8880 - val_loss: 0.3341 - val_accuracy: 0.8718
# Epoch 12/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.3119 - accuracy: 0.8880 - val_loss: 0.3214 - val_accuracy: 0.8718
# Epoch 13/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.3071 - accuracy: 0.8880 - val_loss: 0.3110 - val_accuracy: 0.8718
# Epoch 14/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.2979 - accuracy: 0.8880 - val_loss: 0.2970 - val_accuracy: 0.8718
# Epoch 15/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2890 - accuracy: 0.8880 - val_loss: 0.2860 - val_accuracy: 0.8718
# Epoch 16/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2780 - accuracy: 0.8880 - val_loss: 0.2784 - val_accuracy: 0.8718
# Epoch 17/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2742 - accuracy: 0.8880 - val_loss: 0.2711 - val_accuracy: 0.8718
# Epoch 18/100
# 11/11 [==============================] - 0s 33ms/step - loss: 0.2682 - accuracy: 0.8880 - val_loss: 0.2659 - val_accuracy: 0.8718
# Epoch 19/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2596 - accuracy: 0.8880 - val_loss: 0.2597 - val_accuracy: 0.8718
# Epoch 20/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2513 - accuracy: 0.8897 - val_loss: 0.2714 - val_accuracy: 0.9085
# Epoch 21/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.2549 - accuracy: 0.8970 - val_loss: 0.2622 - val_accuracy: 0.9093
# Epoch 22/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.2496 - accuracy: 0.9013 - val_loss: 0.2473 - val_accuracy: 0.9077
# Epoch 23/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2454 - accuracy: 0.9079 - val_loss: 0.2417 - val_accuracy: 0.9101
# Epoch 24/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2387 - accuracy: 0.9067 - val_loss: 0.2383 - val_accuracy: 0.9101
# Epoch 25/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2380 - accuracy: 0.9103 - val_loss: 0.2395 - val_accuracy: 0.9109
# Epoch 26/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2362 - accuracy: 0.9109 - val_loss: 0.2367 - val_accuracy: 0.9124
# Epoch 27/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2307 - accuracy: 0.9097 - val_loss: 0.2395 - val_accuracy: 0.9085
# Epoch 28/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2333 - accuracy: 0.9110 - val_loss: 0.2511 - val_accuracy: 0.9093
# Epoch 29/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2354 - accuracy: 0.9087 - val_loss: 0.2377 - val_accuracy: 0.9109
# Epoch 30/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2302 - accuracy: 0.9128 - val_loss: 0.2314 - val_accuracy: 0.9116
# Epoch 31/100
# 11/11 [==============================] - 0s 32ms/step - loss: 0.2335 - accuracy: 0.9114 - val_loss: 0.2315 - val_accuracy: 0.9116
# Epoch 32/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2247 - accuracy: 0.9122 - val_loss: 0.2336 - val_accuracy: 0.9140
# Epoch 33/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.2254 - accuracy: 0.9150 - val_loss: 0.2273 - val_accuracy: 0.9156
# Epoch 34/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2236 - accuracy: 0.9152 - val_loss: 0.2263 - val_accuracy: 0.9124
# Epoch 35/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.2197 - accuracy: 0.9152 - val_loss: 0.2237 - val_accuracy: 0.9156
# Epoch 36/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2221 - accuracy: 0.9177 - val_loss: 0.2225 - val_accuracy: 0.9140
# Epoch 37/100
# 11/11 [==============================] - 0s 32ms/step - loss: 0.2214 - accuracy: 0.9163 - val_loss: 0.2196 - val_accuracy: 0.9163
# Epoch 38/100
# 11/11 [==============================] - 1s 47ms/step - loss: 0.2180 - accuracy: 0.9165 - val_loss: 0.2200 - val_accuracy: 0.9148
# Epoch 39/100
# 11/11 [==============================] - 0s 37ms/step - loss: 0.2144 - accuracy: 0.9198 - val_loss: 0.2190 - val_accuracy: 0.9171
# Epoch 40/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2152 - accuracy: 0.9202 - val_loss: 0.2158 - val_accuracy: 0.9156
# Epoch 41/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2136 - accuracy: 0.9204 - val_loss: 0.2157 - val_accuracy: 0.9187
# Epoch 42/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.2089 - accuracy: 0.9222 - val_loss: 0.2128 - val_accuracy: 0.9210
# Epoch 43/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.2095 - accuracy: 0.9202 - val_loss: 0.2182 - val_accuracy: 0.9234
# Epoch 44/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.2182 - accuracy: 0.9157 - val_loss: 0.2244 - val_accuracy: 0.9226
# Epoch 45/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2145 - accuracy: 0.9202 - val_loss: 0.2129 - val_accuracy: 0.9249
# Epoch 46/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.2034 - accuracy: 0.9230 - val_loss: 0.2099 - val_accuracy: 0.9187
# Epoch 47/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2052 - accuracy: 0.9214 - val_loss: 0.2059 - val_accuracy: 0.9249
# Epoch 48/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2029 - accuracy: 0.9234 - val_loss: 0.2052 - val_accuracy: 0.9273
# Epoch 49/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1990 - accuracy: 0.9214 - val_loss: 0.2029 - val_accuracy: 0.9289
# Epoch 50/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2092 - accuracy: 0.9193 - val_loss: 0.2088 - val_accuracy: 0.9257
# Epoch 51/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2009 - accuracy: 0.9230 - val_loss: 0.2059 - val_accuracy: 0.9203
# Epoch 52/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2010 - accuracy: 0.9226 - val_loss: 0.2036 - val_accuracy: 0.9281
# Epoch 53/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1966 - accuracy: 0.9253 - val_loss: 0.2020 - val_accuracy: 0.9265
# Epoch 54/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1984 - accuracy: 0.9212 - val_loss: 0.2022 - val_accuracy: 0.9187
# Epoch 55/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1985 - accuracy: 0.9253 - val_loss: 0.1994 - val_accuracy: 0.9281
# Epoch 56/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1971 - accuracy: 0.9273 - val_loss: 0.2007 - val_accuracy: 0.9289
# Epoch 57/100
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1941 - accuracy: 0.9251 - val_loss: 0.1997 - val_accuracy: 0.9328
# Epoch 58/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1946 - accuracy: 0.9263 - val_loss: 0.1979 - val_accuracy: 0.9234
# Epoch 59/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1951 - accuracy: 0.9249 - val_loss: 0.1983 - val_accuracy: 0.9273
# Epoch 60/100
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1926 - accuracy: 0.9283 - val_loss: 0.1989 - val_accuracy: 0.9187
# Epoch 61/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1960 - accuracy: 0.9286 - val_loss: 0.1960 - val_accuracy: 0.9273
# Epoch 62/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1930 - accuracy: 0.9255 - val_loss: 0.2080 - val_accuracy: 0.9304
# Epoch 63/100
# 11/11 [==============================] - 0s 38ms/step - loss: 0.1925 - accuracy: 0.9271 - val_loss: 0.1982 - val_accuracy: 0.9195
# Epoch 64/100
# 11/11 [==============================] - 1s 59ms/step - loss: 0.1876 - accuracy: 0.9306 - val_loss: 0.1935 - val_accuracy: 0.9289
# Epoch 65/100
# 11/11 [==============================] - 0s 44ms/step - loss: 0.1904 - accuracy: 0.9273 - val_loss: 0.1933 - val_accuracy: 0.9281
# Epoch 66/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1900 - accuracy: 0.9294 - val_loss: 0.1922 - val_accuracy: 0.9320
# Epoch 67/100
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1843 - accuracy: 0.9310 - val_loss: 0.1981 - val_accuracy: 0.9312
# Epoch 68/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1899 - accuracy: 0.9306 - val_loss: 0.1953 - val_accuracy: 0.9320
# Epoch 69/100
# 11/11 [==============================] - 0s 44ms/step - loss: 0.1839 - accuracy: 0.9294 - val_loss: 0.1893 - val_accuracy: 0.9249
# Epoch 70/100
# 11/11 [==============================] - 0s 43ms/step - loss: 0.1838 - accuracy: 0.9300 - val_loss: 0.1889 - val_accuracy: 0.9320
# Epoch 71/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1814 - accuracy: 0.9298 - val_loss: 0.1894 - val_accuracy: 0.9328
# Epoch 72/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1847 - accuracy: 0.9275 - val_loss: 0.1910 - val_accuracy: 0.9312
# Epoch 73/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1827 - accuracy: 0.9333 - val_loss: 0.1850 - val_accuracy: 0.9273
# Epoch 74/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1748 - accuracy: 0.9310 - val_loss: 0.1833 - val_accuracy: 0.9304
# Epoch 75/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1797 - accuracy: 0.9292 - val_loss: 0.1822 - val_accuracy: 0.9312
# Epoch 76/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1789 - accuracy: 0.9326 - val_loss: 0.1813 - val_accuracy: 0.9320
# Epoch 77/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1761 - accuracy: 0.9308 - val_loss: 0.1815 - val_accuracy: 0.9343
# Epoch 78/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1799 - accuracy: 0.9343 - val_loss: 0.1813 - val_accuracy: 0.9320
# Epoch 79/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1767 - accuracy: 0.9349 - val_loss: 0.1818 - val_accuracy: 0.9320
# Epoch 80/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1776 - accuracy: 0.9296 - val_loss: 0.1828 - val_accuracy: 0.9296
# Epoch 81/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1769 - accuracy: 0.9343 - val_loss: 0.1863 - val_accuracy: 0.9343
# Epoch 82/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1792 - accuracy: 0.9326 - val_loss: 0.1800 - val_accuracy: 0.9335
# Epoch 83/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1753 - accuracy: 0.9310 - val_loss: 0.1782 - val_accuracy: 0.9328
# Epoch 84/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1756 - accuracy: 0.9343 - val_loss: 0.1783 - val_accuracy: 0.9296
# Epoch 85/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1758 - accuracy: 0.9308 - val_loss: 0.1806 - val_accuracy: 0.9335
# Epoch 86/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1749 - accuracy: 0.9363 - val_loss: 0.1759 - val_accuracy: 0.9367
# Epoch 87/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1708 - accuracy: 0.9345 - val_loss: 0.1760 - val_accuracy: 0.9359
# Epoch 88/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1708 - accuracy: 0.9314 - val_loss: 0.1748 - val_accuracy: 0.9335
# Epoch 89/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1696 - accuracy: 0.9363 - val_loss: 0.1751 - val_accuracy: 0.9367
# Epoch 90/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1720 - accuracy: 0.9337 - val_loss: 0.1782 - val_accuracy: 0.9343
# Epoch 91/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1749 - accuracy: 0.9341 - val_loss: 0.1747 - val_accuracy: 0.9351
# Epoch 92/100
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1685 - accuracy: 0.9357 - val_loss: 0.1727 - val_accuracy: 0.9343
# Epoch 93/100
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1686 - accuracy: 0.9357 - val_loss: 0.1727 - val_accuracy: 0.9359
# Epoch 94/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1645 - accuracy: 0.9372 - val_loss: 0.1723 - val_accuracy: 0.9351
# Epoch 95/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1754 - accuracy: 0.9324 - val_loss: 0.1769 - val_accuracy: 0.9304
# Epoch 96/100
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1663 - accuracy: 0.9365 - val_loss: 0.1706 - val_accuracy: 0.9359
# Epoch 97/100
# 11/11 [==============================] - 0s 30ms/step - loss: 0.1649 - accuracy: 0.9331 - val_loss: 0.1697 - val_accuracy: 0.9335
# Epoch 98/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1618 - accuracy: 0.9388 - val_loss: 0.1684 - val_accuracy: 0.9343
# Epoch 99/100
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1578 - accuracy: 0.9369 - val_loss: 0.1688 - val_accuracy: 0.9351
# Epoch 100/100
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1641 - accuracy: 0.9335 - val_loss: 0.1689 - val_accuracy: 0.9351

# %%
evaluation=model.evaluate(x_test, y_test, verbose=1)
# Out:
# 50/50 [==============================] - 1s 4ms/step - loss: 0.1653 - accuracy: 0.9400

# %%
pd.DataFrame(history.history)
pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')
