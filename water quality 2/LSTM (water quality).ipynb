# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout,SimpleRNN, LSTM, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
x = data.drop('is_safe', axis = 1)
y = data['is_safe']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)


print(y_train.shape)
print(x_train.shape)
# Out:
# (6394, 1)
# (6394, 16, 1)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(16,1), activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(128, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train,
          y_train,
          batch_size = 500,
          epochs= 50,
          validation_split=0.2)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 4s 108ms/step - loss: 0.5642 - accuracy: 0.8714 - val_loss: 0.4186 - val_accuracy: 0.8718
# Epoch 2/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.3820 - accuracy: 0.8880 - val_loss: 0.3973 - val_accuracy: 0.8718
# Epoch 3/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.3649 - accuracy: 0.8880 - val_loss: 0.3895 - val_accuracy: 0.8718
# Epoch 4/50
# 11/11 [==============================] - 1s 76ms/step - loss: 0.3577 - accuracy: 0.8880 - val_loss: 0.3754 - val_accuracy: 0.8718
# Epoch 5/50
# 11/11 [==============================] - 1s 75ms/step - loss: 0.3537 - accuracy: 0.8880 - val_loss: 0.3755 - val_accuracy: 0.8718
# Epoch 6/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.3515 - accuracy: 0.8880 - val_loss: 0.3715 - val_accuracy: 0.8718
# Epoch 7/50
# 11/11 [==============================] - 1s 84ms/step - loss: 0.3501 - accuracy: 0.8880 - val_loss: 0.3669 - val_accuracy: 0.8718
# Epoch 8/50
# 11/11 [==============================] - 1s 83ms/step - loss: 0.3437 - accuracy: 0.8880 - val_loss: 0.3667 - val_accuracy: 0.8718
# Epoch 9/50
# 11/11 [==============================] - 1s 118ms/step - loss: 0.3394 - accuracy: 0.8880 - val_loss: 0.3568 - val_accuracy: 0.8718
# Epoch 10/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.3277 - accuracy: 0.8880 - val_loss: 0.3424 - val_accuracy: 0.8718
# Epoch 11/50
# 11/11 [==============================] - 1s 83ms/step - loss: 0.3195 - accuracy: 0.8880 - val_loss: 0.3373 - val_accuracy: 0.8718
# Epoch 12/50
# 11/11 [==============================] - 1s 77ms/step - loss: 0.3097 - accuracy: 0.8880 - val_loss: 0.3316 - val_accuracy: 0.8718
# Epoch 13/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.3031 - accuracy: 0.8880 - val_loss: 0.3231 - val_accuracy: 0.8718
# Epoch 14/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2942 - accuracy: 0.8880 - val_loss: 0.3171 - val_accuracy: 0.8718
# Epoch 15/50
# 11/11 [==============================] - 1s 77ms/step - loss: 0.2932 - accuracy: 0.8880 - val_loss: 0.3034 - val_accuracy: 0.8718
# Epoch 16/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2795 - accuracy: 0.8880 - val_loss: 0.2940 - val_accuracy: 0.8718
# Epoch 17/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2703 - accuracy: 0.8911 - val_loss: 0.2993 - val_accuracy: 0.8780
# Epoch 18/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.2702 - accuracy: 0.8991 - val_loss: 0.2796 - val_accuracy: 0.8960
# Epoch 19/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.2585 - accuracy: 0.8999 - val_loss: 0.2622 - val_accuracy: 0.9015
# Epoch 20/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.2465 - accuracy: 0.9065 - val_loss: 0.2553 - val_accuracy: 0.9046
# Epoch 21/50
# 11/11 [==============================] - 1s 113ms/step - loss: 0.2388 - accuracy: 0.9114 - val_loss: 0.2599 - val_accuracy: 0.9062
# Epoch 22/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.2366 - accuracy: 0.9099 - val_loss: 0.2471 - val_accuracy: 0.9085
# Epoch 23/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2307 - accuracy: 0.9152 - val_loss: 0.2371 - val_accuracy: 0.9116
# Epoch 24/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.2388 - accuracy: 0.9114 - val_loss: 0.2979 - val_accuracy: 0.8968
# Epoch 25/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2479 - accuracy: 0.9089 - val_loss: 0.2467 - val_accuracy: 0.9085
# Epoch 26/50
# 11/11 [==============================] - 1s 84ms/step - loss: 0.2297 - accuracy: 0.9107 - val_loss: 0.2382 - val_accuracy: 0.9062
# Epoch 27/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.2267 - accuracy: 0.9114 - val_loss: 0.2418 - val_accuracy: 0.9085
# Epoch 28/50
# 11/11 [==============================] - 1s 84ms/step - loss: 0.2262 - accuracy: 0.9130 - val_loss: 0.2411 - val_accuracy: 0.9109
# Epoch 29/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.2239 - accuracy: 0.9175 - val_loss: 0.2337 - val_accuracy: 0.9093
# Epoch 30/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.2215 - accuracy: 0.9148 - val_loss: 0.2347 - val_accuracy: 0.9101
# Epoch 31/50
# 11/11 [==============================] - 1s 83ms/step - loss: 0.2198 - accuracy: 0.9148 - val_loss: 0.2442 - val_accuracy: 0.8984
# Epoch 32/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.2286 - accuracy: 0.9136 - val_loss: 0.2360 - val_accuracy: 0.9077
# Epoch 33/50
# 11/11 [==============================] - 2s 167ms/step - loss: 0.2208 - accuracy: 0.9148 - val_loss: 0.2290 - val_accuracy: 0.9156
# Epoch 34/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.2154 - accuracy: 0.9191 - val_loss: 0.2294 - val_accuracy: 0.9132
# Epoch 35/50
# 11/11 [==============================] - 1s 77ms/step - loss: 0.2123 - accuracy: 0.9218 - val_loss: 0.2387 - val_accuracy: 0.9171
# Epoch 36/50
# 11/11 [==============================] - 1s 74ms/step - loss: 0.2103 - accuracy: 0.9247 - val_loss: 0.2198 - val_accuracy: 0.9226
# Epoch 37/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.2082 - accuracy: 0.9245 - val_loss: 0.2178 - val_accuracy: 0.9249
# Epoch 38/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.2044 - accuracy: 0.9275 - val_loss: 0.2174 - val_accuracy: 0.9226
# Epoch 39/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.2109 - accuracy: 0.9214 - val_loss: 0.2298 - val_accuracy: 0.9148
# Epoch 40/50
# 11/11 [==============================] - 1s 77ms/step - loss: 0.2046 - accuracy: 0.9247 - val_loss: 0.2201 - val_accuracy: 0.9218
# Epoch 41/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2057 - accuracy: 0.9249 - val_loss: 0.2210 - val_accuracy: 0.9234
# Epoch 42/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.2042 - accuracy: 0.9243 - val_loss: 0.2103 - val_accuracy: 0.9257
# Epoch 43/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.1998 - accuracy: 0.9263 - val_loss: 0.2171 - val_accuracy: 0.9289
# Epoch 44/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.2014 - accuracy: 0.9290 - val_loss: 0.2110 - val_accuracy: 0.9226
# Epoch 45/50
# 11/11 [==============================] - 1s 125ms/step - loss: 0.2006 - accuracy: 0.9300 - val_loss: 0.2086 - val_accuracy: 0.9249
# Epoch 46/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.1958 - accuracy: 0.9284 - val_loss: 0.2096 - val_accuracy: 0.9257
# Epoch 47/50
# 11/11 [==============================] - 1s 76ms/step - loss: 0.1950 - accuracy: 0.9273 - val_loss: 0.2063 - val_accuracy: 0.9249
# Epoch 48/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.1939 - accuracy: 0.9281 - val_loss: 0.2092 - val_accuracy: 0.9218
# Epoch 49/50
# 11/11 [==============================] - 1s 76ms/step - loss: 0.1954 - accuracy: 0.9284 - val_loss: 0.2057 - val_accuracy: 0.9265
# Epoch 50/50
# 11/11 [==============================] - 1s 76ms/step - loss: 0.1929 - accuracy: 0.9290 - val_loss: 0.2132 - val_accuracy: 0.9218

# %%
evaluation = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 50/50 [==============================] - 1s 8ms/step - loss: 0.2075 - accuracy: 0.9212

# %%
pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
