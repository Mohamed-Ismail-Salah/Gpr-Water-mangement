# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from keras.models import Model
from keras.models import Sequential
from keras.preprocessing import sequence
from keras.layers import Dense,GRU, Conv1D, Flatten,LSTM, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from keras.layers import Dense, Conv2D, MaxPool1D, Flatten, Dropout # importing dense layer
from sklearn import preprocessing
from keras.layers.embeddings import Embedding
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer

# %%
dataset = pd.read_csv('../input/rainfall-prediction/dataset1.csv')

# %%
dataset
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# 0        49      yes       9.3                    80.0       26.3
# 1        83      yes       0.6                    50.0       15.3
# 2        91      yes       0.0                    40.0       14.2
# 3        88      yes       1.0                    50.0       16.9
# 4        81      yes       0.0                    40.0       13.7
# ..      ...      ...       ...                     ...        ...
# 361      90      yes       0.0                    30.0       18.4
# 362      85      yes       1.0                    20.0       25.9
# 363      78      yes       4.6                    70.0       33.4
# 364      86      yes       1.2                    20.0       20.9
# 365      66       no       5.7                    20.0       23.3
#
# [366 rows x 12 columns]

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
# remove attribute 'day'
dataset.drop(['day'],axis=1,inplace=True)
dataset.shape
# Out:
# (366, 11)

# %%
##dataset.label.value_counts()

# %%
#dataset = pd.get_dummies(dataset,columns=['rainfall'],prefix="",prefix_sep="")  
#dataset

# %%
#y_train_multi= dataset[['yes','no']]
#X_train_multi= dataset.drop(labels=['yes','no'], axis=1)

#print('X_train has shape:',X_train_multi.shape,'\ny_train has shape:',y_train_multi.shape)

# %%
dataset['rainfall'].value_counts()
# Out:
# yes    249
# no     117
# Name: rainfall, dtype: int64

# %%
multi_label = pd.DataFrame(dataset.rainfall)

le = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le.fit_transform)
dataset['rainfall'] = enc_label
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
y_train= dataset[['rainfall']]
X_train= dataset.drop(labels=['rainfall'], axis=1)

print('X_train has shape:',X_train.shape,'\ny_train has shape:',y_train.shape)
# Out:
# X_train has shape: (366, 10)
# y_train has shape: (366, 1)

# %%
X_train=np.array(X_train)
y_train=np.array(y_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.20, random_state=42)

# %%
sc_x = StandardScaler()
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (292, 10, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test.shape
# Out:
# (74, 10, 1)

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pressure                366 non-null    float64
#  1   maxtemp                 366 non-null    float64
#  2   temparature             366 non-null    float64
#  3   mintemp                 366 non-null    float64
#  4   dewpoint                366 non-null    float64
#  5   humidity                366 non-null    int64
#  6   cloud                   366 non-null    int64
#  7   rainfall                366 non-null    int64
#  8   sunshine                366 non-null    float64
#  9            winddirection  365 non-null    float64
#  10  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 31.6 KB

# %%
#from sklearn.preprocessing import LabelBinarizer

#y_train= LabelBinarizer().fit_transform(y_train)
 
#x_train=np.asarray(x_train).astype(np.float32)

# %%
model = Sequential()
model.add(Conv1D(32, 3, padding="same",input_shape = (X_train.shape[1], 1), activation='relu'))
#nn.add(MaxPooling1D(pool_size=(2)))
#cnn.add(Flatten())
#model = Sequential()
#model.add(TimeDistributed(cnn, ...))
model.add(Dropout(0.2))

model.add(LSTM(128,input_shape = (X_train.shape[1], 2)))
model.add(Dropout(0.2))
# Third LSTM layer
model.add(Dense(10))
model.add(Dropout(0.2))



model.add(Dense(units= 1,activation='sigmoid' ))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential_244"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_61 (Conv1D)           (None, 10, 32)            128
# _________________________________________________________________
# dropout_475 (Dropout)        (None, 10, 32)            0
# _________________________________________________________________
# lstm_60 (LSTM)               (None, 128)               82432
# _________________________________________________________________
# dropout_476 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_577 (Dense)            (None, 10)                1290
# _________________________________________________________________
# dropout_477 (Dropout)        (None, 10)                0
# _________________________________________________________________
# dense_578 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 83,861
# Trainable params: 83,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=100, batch_size=500,validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6944 - accuracy: 0.4678 - val_loss: nan - val_accuracy: 0.7458
# Epoch 2/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6765 - accuracy: 0.6609 - val_loss: nan - val_accuracy: 0.7458
# Epoch 3/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6676 - accuracy: 0.6524 - val_loss: nan - val_accuracy: 0.7458
# Epoch 4/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6602 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 5/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6522 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 6/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6455 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 7/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6470 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 8/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6351 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 9/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6357 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 10/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6396 - accuracy: 0.6695 - val_loss: nan - val_accuracy: 0.7458
# Epoch 11/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6451 - accuracy: 0.6695 - val_loss: nan - val_accuracy: 0.7797
# Epoch 12/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6385 - accuracy: 0.6781 - val_loss: nan - val_accuracy: 0.7966
# Epoch 13/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6227 - accuracy: 0.6996 - val_loss: nan - val_accuracy: 0.7458
# Epoch 14/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6260 - accuracy: 0.6867 - val_loss: nan - val_accuracy: 0.6949
# Epoch 15/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6218 - accuracy: 0.6824 - val_loss: nan - val_accuracy: 0.6949
# Epoch 16/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6149 - accuracy: 0.6867 - val_loss: nan - val_accuracy: 0.6949
# Epoch 17/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6186 - accuracy: 0.6781 - val_loss: nan - val_accuracy: 0.6949
# Epoch 18/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6215 - accuracy: 0.6867 - val_loss: nan - val_accuracy: 0.6949
# Epoch 19/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6180 - accuracy: 0.6824 - val_loss: nan - val_accuracy: 0.6949
# Epoch 20/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6162 - accuracy: 0.6996 - val_loss: nan - val_accuracy: 0.7458
# Epoch 21/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6068 - accuracy: 0.6910 - val_loss: nan - val_accuracy: 0.7458
# Epoch 22/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6064 - accuracy: 0.6953 - val_loss: nan - val_accuracy: 0.7797
# Epoch 23/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6073 - accuracy: 0.6867 - val_loss: nan - val_accuracy: 0.7966
# Epoch 24/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5959 - accuracy: 0.6910 - val_loss: nan - val_accuracy: 0.7797
# Epoch 25/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6019 - accuracy: 0.6867 - val_loss: nan - val_accuracy: 0.7797
# Epoch 26/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5995 - accuracy: 0.6953 - val_loss: nan - val_accuracy: 0.7966
# Epoch 27/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5784 - accuracy: 0.6996 - val_loss: nan - val_accuracy: 0.7966
# Epoch 28/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5827 - accuracy: 0.7039 - val_loss: nan - val_accuracy: 0.7966
# Epoch 29/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5758 - accuracy: 0.7167 - val_loss: nan - val_accuracy: 0.7966
# Epoch 30/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5773 - accuracy: 0.7210 - val_loss: nan - val_accuracy: 0.8305
# Epoch 31/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5678 - accuracy: 0.7253 - val_loss: nan - val_accuracy: 0.8305
# Epoch 32/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5628 - accuracy: 0.7382 - val_loss: nan - val_accuracy: 0.8305
# Epoch 33/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5512 - accuracy: 0.7253 - val_loss: nan - val_accuracy: 0.8136
# Epoch 34/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5465 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.8136
# Epoch 35/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5285 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.8136
# Epoch 36/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5133 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8136
# Epoch 37/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4872 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8136
# Epoch 38/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4954 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8136
# Epoch 39/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4857 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8136
# Epoch 40/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4459 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.7966
# Epoch 41/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4688 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.7966
# Epoch 42/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4681 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.7966
# Epoch 43/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4755 - accuracy: 0.7682 - val_loss: nan - val_accuracy: 0.7966
# Epoch 44/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4665 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8136
# Epoch 45/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4748 - accuracy: 0.7639 - val_loss: nan - val_accuracy: 0.7797
# Epoch 46/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4305 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8136
# Epoch 47/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4579 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.8305
# Epoch 48/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4476 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.8136
# Epoch 49/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4296 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8136
# Epoch 50/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4221 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 51/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4360 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8305
# Epoch 52/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4393 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8305
# Epoch 53/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4231 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 54/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4016 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8475
# Epoch 55/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4174 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8475
# Epoch 56/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4181 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 57/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4406 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.8475
# Epoch 58/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4296 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8475
# Epoch 59/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4247 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8475
# Epoch 60/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4145 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8475
# Epoch 61/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4155 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8475
# Epoch 62/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4008 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 63/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4055 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8136
# Epoch 64/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4368 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.7966
# Epoch 65/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4089 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7966
# Epoch 66/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4066 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.7966
# Epoch 67/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4040 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.7966
# Epoch 68/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4120 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8475
# Epoch 69/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4111 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.8475
# Epoch 70/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4079 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8475
# Epoch 71/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4168 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.7966
# Epoch 72/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3951 - accuracy: 0.8283 - val_loss: nan - val_accuracy: 0.7966
# Epoch 73/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3977 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.7966
# Epoch 74/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3898 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.7966
# Epoch 75/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3800 - accuracy: 0.8283 - val_loss: nan - val_accuracy: 0.7966
# Epoch 76/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4091 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8475
# Epoch 77/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3958 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8475
# Epoch 78/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3953 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 79/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3909 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 80/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3956 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 81/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3881 - accuracy: 0.8283 - val_loss: nan - val_accuracy: 0.8475
# Epoch 82/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3890 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8475
# Epoch 83/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3895 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8475
# Epoch 84/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3996 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.8305
# Epoch 85/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4052 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.8305
# Epoch 86/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3941 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8305
# Epoch 87/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3812 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 88/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3905 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 89/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3910 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 90/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3819 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8305
# Epoch 91/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3940 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8305
# Epoch 92/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3860 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.8305
# Epoch 93/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3963 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 94/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4020 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8136
# Epoch 95/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3795 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.8305
# Epoch 96/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3991 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 97/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3903 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 98/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3909 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 99/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4057 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.8136
# Epoch 100/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3932 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8136

# %%
# predicting target attribute on testing dataset
score =model.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4879 - accuracy: 0.7568
# Test loss: 0.48791608214378357
# Test accuracy: 0.7567567825317383

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")

pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
