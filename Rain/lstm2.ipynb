# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers

from keras.models import Model
from keras.models import Sequential
from keras.preprocessing import sequence
from keras.layers import Dense,GRU, Conv1D, Flatten,LSTM, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout # importing dense layer
from sklearn import preprocessing
from keras.layers.embeddings import Embedding
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer

# %%
dataset = pd.read_csv('../input/rainfall-prediction/dataset1.csv')

# %%
dataset
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# 0        49      yes       9.3                    80.0       26.3
# 1        83      yes       0.6                    50.0       15.3
# 2        91      yes       0.0                    40.0       14.2
# 3        88      yes       1.0                    50.0       16.9
# 4        81      yes       0.0                    40.0       13.7
# ..      ...      ...       ...                     ...        ...
# 361      90      yes       0.0                    30.0       18.4
# 362      85      yes       1.0                    20.0       25.9
# 363      78      yes       4.6                    70.0       33.4
# 364      86      yes       1.2                    20.0       20.9
# 365      66       no       5.7                    20.0       23.3
#
# [366 rows x 12 columns]

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
# remove attribute 'day'
dataset.drop(['day'],axis=1,inplace=True)
dataset.shape
# Out:
# (366, 11)

# %%
##dataset.label.value_counts()

# %%
#dataset = pd.get_dummies(dataset,columns=['rainfall'],prefix="",prefix_sep="")  
#dataset

# %%
#y_train_multi= dataset[['yes','no']]
#X_train_multi= dataset.drop(labels=['yes','no'], axis=1)

#print('X_train has shape:',X_train_multi.shape,'\ny_train has shape:',y_train_multi.shape)

# %%
dataset['rainfall'].value_counts()
# Out:
# yes    249
# no     117
# Name: rainfall, dtype: int64

# %%
multi_label = pd.DataFrame(dataset.rainfall)

le = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le.fit_transform)
dataset['rainfall'] = enc_label
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
y_train= dataset[['rainfall']]
X_train= dataset.drop(labels=['rainfall'], axis=1)

print('X_train has shape:',X_train.shape,'\ny_train has shape:',y_train.shape)
# Out:
# X_train has shape: (366, 10)
# y_train has shape: (366, 1)

# %%
X_train=np.array(X_train)
y_train=np.array(y_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.20, random_state=42)

# %%
sc_x = StandardScaler()
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (292, 10, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test.shape
# Out:
# (74, 10, 1)

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pressure                366 non-null    float64
#  1   maxtemp                 366 non-null    float64
#  2   temparature             366 non-null    float64
#  3   mintemp                 366 non-null    float64
#  4   dewpoint                366 non-null    float64
#  5   humidity                366 non-null    int64
#  6   cloud                   366 non-null    int64
#  7   rainfall                366 non-null    int64
#  8   sunshine                366 non-null    float64
#  9            winddirection  365 non-null    float64
#  10  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 31.6 KB

# %%
#from sklearn.preprocessing import LabelBinarizer

#y_train= LabelBinarizer().fit_transform(y_train)
 
#x_train=np.asarray(x_train).astype(np.float32)

# %%
from keras.layers import LSTM
regressor = Sequential()

regressor.add(LSTM(units = 256, return_sequences = True, input_shape = (X_train.shape[1], 1)))
#regressor.add(Dense(units = 64, activation='relu'))

regressor.add(Dropout(0.25))




regressor.add(LSTM(units = 128, return_sequences = True))
#regressor.add(Dense(units = 64, activation='relu'))

regressor.add(Dropout(0.25))


regressor.add(LSTM(units = 128, return_sequences = True))
#regressor.add(Dense(units = 64, activation='relu'))

regressor.add(Dropout(0.25))

regressor.add(LSTM(units = 128))
#regressor.add(Dense(units = 32, activation='relu'))

#regressor.add(Dropout(0.25))




regressor.add(Dense(1, activation='sigmoid'))

# %%
# defining loss function, optimizer, metrics and then compiling model
regressor.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
regressor.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_116 (LSTM)              (None, 10, 256)           264192
# _________________________________________________________________
# dropout_114 (Dropout)        (None, 10, 256)           0
# _________________________________________________________________
# lstm_117 (LSTM)              (None, 10, 128)           197120
# _________________________________________________________________
# dropout_115 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_118 (LSTM)              (None, 10, 128)           131584
# _________________________________________________________________
# dropout_116 (Dropout)        (None, 10, 128)           0
# _________________________________________________________________
# lstm_119 (LSTM)              (None, 128)               131584
# _________________________________________________________________
# dense_85 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 724,609
# Trainable params: 724,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = regressor.fit(X_train, y_train, epochs=100, batch_size=500,validation_split=0.2)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6935 - accuracy: 0.4034 - val_loss: nan - val_accuracy: 0.6949
# Epoch 2/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6877 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.6949
# Epoch 3/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6809 - accuracy: 0.6524 - val_loss: nan - val_accuracy: 0.6949
# Epoch 4/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6723 - accuracy: 0.6524 - val_loss: nan - val_accuracy: 0.6780
# Epoch 5/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6618 - accuracy: 0.6481 - val_loss: nan - val_accuracy: 0.6780
# Epoch 6/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6513 - accuracy: 0.6395 - val_loss: nan - val_accuracy: 0.6780
# Epoch 7/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6442 - accuracy: 0.6352 - val_loss: nan - val_accuracy: 0.7119
# Epoch 8/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6426 - accuracy: 0.6438 - val_loss: nan - val_accuracy: 0.7627
# Epoch 9/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6387 - accuracy: 0.6738 - val_loss: nan - val_accuracy: 0.7627
# Epoch 10/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6319 - accuracy: 0.6738 - val_loss: nan - val_accuracy: 0.7458
# Epoch 11/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6308 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 12/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6294 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 13/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6304 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 14/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6302 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 15/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6273 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 16/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6215 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 17/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6178 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7627
# Epoch 18/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6115 - accuracy: 0.6695 - val_loss: nan - val_accuracy: 0.7627
# Epoch 19/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6082 - accuracy: 0.6738 - val_loss: nan - val_accuracy: 0.7797
# Epoch 20/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5979 - accuracy: 0.6910 - val_loss: nan - val_accuracy: 0.7627
# Epoch 21/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5888 - accuracy: 0.6996 - val_loss: nan - val_accuracy: 0.7797
# Epoch 22/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5752 - accuracy: 0.7039 - val_loss: nan - val_accuracy: 0.7288
# Epoch 23/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5681 - accuracy: 0.7382 - val_loss: nan - val_accuracy: 0.7288
# Epoch 24/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5547 - accuracy: 0.7339 - val_loss: nan - val_accuracy: 0.7119
# Epoch 25/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5440 - accuracy: 0.7339 - val_loss: nan - val_accuracy: 0.7119
# Epoch 26/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5358 - accuracy: 0.7253 - val_loss: nan - val_accuracy: 0.6949
# Epoch 27/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5457 - accuracy: 0.7210 - val_loss: nan - val_accuracy: 0.7119
# Epoch 28/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5555 - accuracy: 0.7339 - val_loss: nan - val_accuracy: 0.7119
# Epoch 29/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5403 - accuracy: 0.7039 - val_loss: nan - val_accuracy: 0.6949
# Epoch 30/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5439 - accuracy: 0.6781 - val_loss: nan - val_accuracy: 0.6949
# Epoch 31/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5269 - accuracy: 0.6996 - val_loss: nan - val_accuracy: 0.7119
# Epoch 32/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5299 - accuracy: 0.7253 - val_loss: nan - val_accuracy: 0.7288
# Epoch 33/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5187 - accuracy: 0.7425 - val_loss: nan - val_accuracy: 0.7288
# Epoch 34/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5150 - accuracy: 0.7425 - val_loss: nan - val_accuracy: 0.7119
# Epoch 35/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5186 - accuracy: 0.7382 - val_loss: nan - val_accuracy: 0.7288
# Epoch 36/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5168 - accuracy: 0.7468 - val_loss: nan - val_accuracy: 0.7119
# Epoch 37/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5165 - accuracy: 0.7554 - val_loss: nan - val_accuracy: 0.7627
# Epoch 38/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5070 - accuracy: 0.7682 - val_loss: nan - val_accuracy: 0.7458
# Epoch 39/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5055 - accuracy: 0.7511 - val_loss: nan - val_accuracy: 0.7458
# Epoch 40/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5046 - accuracy: 0.7554 - val_loss: nan - val_accuracy: 0.7458
# Epoch 41/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5023 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.7288
# Epoch 42/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4900 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.7288
# Epoch 43/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4900 - accuracy: 0.7639 - val_loss: nan - val_accuracy: 0.7458
# Epoch 44/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4857 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.7288
# Epoch 45/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4827 - accuracy: 0.7682 - val_loss: nan - val_accuracy: 0.7119
# Epoch 46/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4863 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.7458
# Epoch 47/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4761 - accuracy: 0.7639 - val_loss: nan - val_accuracy: 0.7458
# Epoch 48/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4765 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.7458
# Epoch 49/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4749 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7797
# Epoch 50/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4764 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.8136
# Epoch 51/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4714 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7458
# Epoch 52/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4621 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7627
# Epoch 53/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4666 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7627
# Epoch 54/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4695 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7797
# Epoch 55/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4617 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 56/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4608 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.7797
# Epoch 57/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4596 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 58/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4566 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7966
# Epoch 59/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4518 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7797
# Epoch 60/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4524 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.7797
# Epoch 61/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4515 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7797
# Epoch 62/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4524 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 63/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4503 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7627
# Epoch 64/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4404 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.7797
# Epoch 65/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4428 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7966
# Epoch 66/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4342 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.7966
# Epoch 67/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4460 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7966
# Epoch 68/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4416 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7966
# Epoch 69/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4348 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.7797
# Epoch 70/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4404 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.7797
# Epoch 71/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4388 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.7966
# Epoch 72/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4324 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7797
# Epoch 73/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4436 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7797
# Epoch 74/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4375 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.7966
# Epoch 75/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4423 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.7966
# Epoch 76/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4391 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.7966
# Epoch 77/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4293 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7797
# Epoch 78/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4198 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 79/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4294 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7966
# Epoch 80/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4267 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7966
# Epoch 81/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4294 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7966
# Epoch 82/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4278 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 83/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4258 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.7797
# Epoch 84/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4210 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.7966
# Epoch 85/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4293 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7797
# Epoch 86/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4210 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7966
# Epoch 87/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4194 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8136
# Epoch 88/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4213 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7966
# Epoch 89/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4241 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.7966
# Epoch 90/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4255 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.7966
# Epoch 91/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4167 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.7966
# Epoch 92/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4133 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 93/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4052 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.7966
# Epoch 94/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4168 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.7966
# Epoch 95/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4252 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.7966
# Epoch 96/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4223 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 97/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4056 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.7797
# Epoch 98/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4144 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8136
# Epoch 99/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4000 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.7797
# Epoch 100/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4226 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.7966

# %%
# predicting target attribute on testing dataset
score =regressor.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5196 - accuracy: 0.7703
# Test loss: 0.519626259803772
# Test accuracy: 0.7702702879905701

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")

pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
