# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout # importing dense layer
from sklearn import preprocessing
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer

# %%
dataset = pd.read_csv('../input/rainfall-prediction/dataset1.csv')

# %%
dataset
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# 0        49      yes       9.3                    80.0       26.3
# 1        83      yes       0.6                    50.0       15.3
# 2        91      yes       0.0                    40.0       14.2
# 3        88      yes       1.0                    50.0       16.9
# 4        81      yes       0.0                    40.0       13.7
# ..      ...      ...       ...                     ...        ...
# 361      90      yes       0.0                    30.0       18.4
# 362      85      yes       1.0                    20.0       25.9
# 363      78      yes       4.6                    70.0       33.4
# 364      86      yes       1.2                    20.0       20.9
# 365      66       no       5.7                    20.0       23.3
#
# [366 rows x 12 columns]

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
# remove attribute 'day'
dataset.drop(['day'],axis=1,inplace=True)
dataset.shape
# Out:
# (366, 11)

# %%
##dataset.label.value_counts()

# %%
#dataset = pd.get_dummies(dataset,columns=['rainfall'],prefix="",prefix_sep="")  
#dataset

# %%
#y_train_multi= dataset[['yes','no']]
#X_train_multi= dataset.drop(labels=['yes','no'], axis=1)

#print('X_train has shape:',X_train_multi.shape,'\ny_train has shape:',y_train_multi.shape)

# %%
dataset['rainfall'].value_counts()
# Out:
# yes    249
# no     117
# Name: rainfall, dtype: int64

# %%
multi_label = pd.DataFrame(dataset.rainfall)

le = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le.fit_transform)
dataset['rainfall'] = enc_label
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
y_train= dataset[['rainfall']]
X_train= dataset.drop(labels=['rainfall'], axis=1)

print('X_train has shape:',X_train.shape,'\ny_train has shape:',y_train.shape)
# Out:
# X_train has shape: (366, 10)
# y_train has shape: (366, 1)

# %%
X_train=np.array(X_train)
y_train=np.array(y_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.20, random_state=42)

# %%
sc_x = StandardScaler()
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (292, 10, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test.shape
# Out:
# (74, 10, 1)

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pressure                366 non-null    float64
#  1   maxtemp                 366 non-null    float64
#  2   temparature             366 non-null    float64
#  3   mintemp                 366 non-null    float64
#  4   dewpoint                366 non-null    float64
#  5   humidity                366 non-null    int64
#  6   cloud                   366 non-null    int64
#  7   rainfall                366 non-null    int64
#  8   sunshine                366 non-null    float64
#  9            winddirection  365 non-null    float64
#  10  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 31.6 KB

# %%
#from sklearn.preprocessing import LabelBinarizer

#y_train= LabelBinarizer().fit_transform(y_train)
 
#x_train=np.asarray(x_train).astype(np.float32)

# %%
    model = Sequential()
    model.add(SimpleRNN(128, input_shape= (X_train.shape[1], 1), activation='relu'))
    model.add(Dropout(.2))

    model.add(Dense(units= 100,activation='softmax' ))
    model.add(Dropout(.2))
    model.add(Dense(units= 20,activation='relu' ))
    model.add(Dropout(.2))
    

    
    model.add(Dense(units= 1,activation='sigmoid' ))

# %%
# defining loss function, optimizer, metrics and then compiling model
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
model.summary()
# Out:
# Model: "sequential_182"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_183 (SimpleRNN)   (None, 128)               16640
# _________________________________________________________________
# dropout_363 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_452 (Dense)            (None, 100)               12900
# _________________________________________________________________
# dropout_364 (Dropout)        (None, 100)               0
# _________________________________________________________________
# dense_453 (Dense)            (None, 20)                2020
# _________________________________________________________________
# dropout_365 (Dropout)        (None, 20)                0
# _________________________________________________________________
# dense_454 (Dense)            (None, 1)                 21
# =================================================================
# Total params: 31,581
# Trainable params: 31,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = model.fit(X_train, y_train, epochs=100, batch_size=200,validation_split=0.2)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 223ms/step - loss: 0.6940 - accuracy: 0.4120 - val_loss: nan - val_accuracy: 0.7458
# Epoch 2/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6925 - accuracy: 0.5708 - val_loss: nan - val_accuracy: 0.7458
# Epoch 3/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6903 - accuracy: 0.6481 - val_loss: nan - val_accuracy: 0.7458
# Epoch 4/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6884 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 5/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6863 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 6/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6843 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 7/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6803 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 8/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6752 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 9/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6672 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 10/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6466 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 11/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6374 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 12/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6296 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 13/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6328 - accuracy: 0.6609 - val_loss: nan - val_accuracy: 0.7458
# Epoch 14/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6382 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 15/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6222 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 16/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6103 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 17/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6044 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 18/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5993 - accuracy: 0.6567 - val_loss: nan - val_accuracy: 0.7458
# Epoch 19/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5917 - accuracy: 0.6695 - val_loss: nan - val_accuracy: 0.7458
# Epoch 20/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6087 - accuracy: 0.6609 - val_loss: nan - val_accuracy: 0.7458
# Epoch 21/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5873 - accuracy: 0.6695 - val_loss: nan - val_accuracy: 0.7458
# Epoch 22/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5875 - accuracy: 0.6781 - val_loss: nan - val_accuracy: 0.7458
# Epoch 23/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5823 - accuracy: 0.6953 - val_loss: nan - val_accuracy: 0.7797
# Epoch 24/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5854 - accuracy: 0.7082 - val_loss: nan - val_accuracy: 0.8644
# Epoch 25/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5852 - accuracy: 0.7253 - val_loss: nan - val_accuracy: 0.8475
# Epoch 26/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5702 - accuracy: 0.7682 - val_loss: nan - val_accuracy: 0.8475
# Epoch 27/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5640 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8305
# Epoch 28/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5625 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8644
# Epoch 29/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5509 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8644
# Epoch 30/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5727 - accuracy: 0.7897 - val_loss: nan - val_accuracy: 0.8644
# Epoch 31/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5449 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8305
# Epoch 32/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5595 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8475
# Epoch 33/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5546 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8814
# Epoch 34/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5434 - accuracy: 0.8369 - val_loss: nan - val_accuracy: 0.8814
# Epoch 35/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5431 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8644
# Epoch 36/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5528 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8136
# Epoch 37/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5404 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.8136
# Epoch 38/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5392 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.8475
# Epoch 39/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5487 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8136
# Epoch 40/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5492 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8305
# Epoch 41/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5330 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8136
# Epoch 42/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5243 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8644
# Epoch 43/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5313 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8644
# Epoch 44/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5204 - accuracy: 0.8069 - val_loss: nan - val_accuracy: 0.8305
# Epoch 45/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5323 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 46/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5186 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8305
# Epoch 47/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5317 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8305
# Epoch 48/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5204 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8475
# Epoch 49/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5105 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8305
# Epoch 50/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5050 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8136
# Epoch 51/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4995 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8305
# Epoch 52/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5312 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8136
# Epoch 53/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4826 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.8475
# Epoch 54/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5160 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8305
# Epoch 55/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5115 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.7966
# Epoch 56/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5188 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.7627
# Epoch 57/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5099 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.7288
# Epoch 58/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5333 - accuracy: 0.7597 - val_loss: nan - val_accuracy: 0.7458
# Epoch 59/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5163 - accuracy: 0.7682 - val_loss: nan - val_accuracy: 0.7797
# Epoch 60/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5046 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8136
# Epoch 61/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4900 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.7966
# Epoch 62/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4960 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8475
# Epoch 63/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4847 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8644
# Epoch 64/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4955 - accuracy: 0.8283 - val_loss: nan - val_accuracy: 0.8475
# Epoch 65/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4795 - accuracy: 0.7940 - val_loss: nan - val_accuracy: 0.8644
# Epoch 66/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5066 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8644
# Epoch 67/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4884 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8644
# Epoch 68/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5022 - accuracy: 0.7811 - val_loss: nan - val_accuracy: 0.8644
# Epoch 69/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5044 - accuracy: 0.7725 - val_loss: nan - val_accuracy: 0.8814
# Epoch 70/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5224 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 71/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4853 - accuracy: 0.7854 - val_loss: nan - val_accuracy: 0.8475
# Epoch 72/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4642 - accuracy: 0.8283 - val_loss: nan - val_accuracy: 0.8475
# Epoch 73/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4775 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8475
# Epoch 74/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4937 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8475
# Epoch 75/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4814 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8475
# Epoch 76/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4655 - accuracy: 0.8369 - val_loss: nan - val_accuracy: 0.8475
# Epoch 77/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4800 - accuracy: 0.8455 - val_loss: nan - val_accuracy: 0.8644
# Epoch 78/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4777 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8475
# Epoch 79/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4671 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.8644
# Epoch 80/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4649 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8475
# Epoch 81/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4620 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8305
# Epoch 82/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4723 - accuracy: 0.8326 - val_loss: nan - val_accuracy: 0.8305
# Epoch 83/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4547 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 84/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4902 - accuracy: 0.7768 - val_loss: nan - val_accuracy: 0.8475
# Epoch 85/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4580 - accuracy: 0.8240 - val_loss: nan - val_accuracy: 0.8305
# Epoch 86/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4593 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8305
# Epoch 87/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4311 - accuracy: 0.8455 - val_loss: nan - val_accuracy: 0.8475
# Epoch 88/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4781 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8475
# Epoch 89/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.4587 - accuracy: 0.8197 - val_loss: nan - val_accuracy: 0.8305
# Epoch 90/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4618 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 91/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4558 - accuracy: 0.7983 - val_loss: nan - val_accuracy: 0.8305
# Epoch 92/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4400 - accuracy: 0.8584 - val_loss: nan - val_accuracy: 0.8305
# Epoch 93/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4661 - accuracy: 0.8112 - val_loss: nan - val_accuracy: 0.8136
# Epoch 94/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4603 - accuracy: 0.8455 - val_loss: nan - val_accuracy: 0.8475
# Epoch 95/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4291 - accuracy: 0.8498 - val_loss: nan - val_accuracy: 0.8644
# Epoch 96/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4748 - accuracy: 0.8412 - val_loss: nan - val_accuracy: 0.8475
# Epoch 97/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4479 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8475
# Epoch 98/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4349 - accuracy: 0.8455 - val_loss: nan - val_accuracy: 0.8475
# Epoch 99/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4467 - accuracy: 0.8155 - val_loss: nan - val_accuracy: 0.8305
# Epoch 100/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4564 - accuracy: 0.8026 - val_loss: nan - val_accuracy: 0.8136

# %%
# predicting target attribute on testing dataset
score =model.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5538 - accuracy: 0.7162
# Test loss: 0.5537979602813721
# Test accuracy: 0.7162162065505981

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")

pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
