# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import LSTM
#from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional     
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout

# %%
df = pd.read_csv('../input/water-potability/water_potability.csv')
df.shape
# Out:
# (3276, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB
# None

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
X = df.drop(["Potability"], axis=1)
y = df["Potability"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
X_train.shape
# Out:
# (2620, 9, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
X_test.shape
# Out:
# (656, 9, 1)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(9,1)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='softmax'))
#model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.compile(optimizer = 'adam', loss = 'binary_crossentropy')
#history = model.fit(X_train,y_train,epochs=50,batch_size=100)
model.fit(x=X_train, y=y_train,  epochs=100, validation_data=(X_test, y_test), verbose=1  )
# Out:
# Epoch 1/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.6726 - val_loss: 0.6464
# Epoch 2/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.6529 - val_loss: 0.6438
# Epoch 3/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.6413 - val_loss: 0.6209
# Epoch 4/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.6398 - val_loss: 0.6230
# Epoch 5/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.6328 - val_loss: 0.6178
# Epoch 6/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.6289 - val_loss: 0.6177
# Epoch 7/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.6251 - val_loss: 0.6102
# Epoch 8/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.6245 - val_loss: 0.6164
# Epoch 9/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.6105 - val_loss: 0.6099
# Epoch 10/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.6084 - val_loss: 0.6045
# Epoch 11/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.6092 - val_loss: 0.6039
# Epoch 12/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.6077 - val_loss: 0.6133
# Epoch 13/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5999 - val_loss: 0.6046
# Epoch 14/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5980 - val_loss: 0.5995
# Epoch 15/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.5965 - val_loss: 0.5976
# Epoch 16/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5942 - val_loss: 0.5994
# Epoch 17/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.5929 - val_loss: 0.6022
# Epoch 18/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.5832 - val_loss: 0.5976
# Epoch 19/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5804 - val_loss: 0.6001
# Epoch 20/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5855 - val_loss: 0.5946
# Epoch 21/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5819 - val_loss: 0.5971
# Epoch 22/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5821 - val_loss: 0.5994
# Epoch 23/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5774 - val_loss: 0.5970
# Epoch 24/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5681 - val_loss: 0.5986
# Epoch 25/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5724 - val_loss: 0.5990
# Epoch 26/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5681 - val_loss: 0.5983
# Epoch 27/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.5666 - val_loss: 0.5938
# Epoch 28/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5672 - val_loss: 0.6016
# Epoch 29/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5587 - val_loss: 0.6032
# Epoch 30/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5628 - val_loss: 0.5947
# Epoch 31/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5604 - val_loss: 0.5922
# Epoch 32/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5531 - val_loss: 0.5939
# Epoch 33/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5582 - val_loss: 0.5999
# Epoch 34/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5497 - val_loss: 0.6058
# Epoch 35/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5468 - val_loss: 0.5906
# Epoch 36/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5533 - val_loss: 0.5890
# Epoch 37/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5476 - val_loss: 0.5931
# Epoch 38/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5510 - val_loss: 0.5949
# Epoch 39/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5448 - val_loss: 0.5898
# Epoch 40/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5383 - val_loss: 0.5943
# Epoch 41/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5331 - val_loss: 0.6014
# Epoch 42/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5412 - val_loss: 0.5887
# Epoch 43/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5332 - val_loss: 0.5889
# Epoch 44/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5339 - val_loss: 0.5944
# Epoch 45/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5359 - val_loss: 0.6003
# Epoch 46/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5330 - val_loss: 0.6014
# Epoch 47/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5232 - val_loss: 0.6108
# Epoch 48/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5280 - val_loss: 0.5936
# Epoch 49/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.5195 - val_loss: 0.6031
# Epoch 50/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5230 - val_loss: 0.6248
# Epoch 51/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5153 - val_loss: 0.6023
# Epoch 52/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5279 - val_loss: 0.5997
# Epoch 53/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5176 - val_loss: 0.5959
# Epoch 54/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5278 - val_loss: 0.6084
# Epoch 55/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5162 - val_loss: 0.6115
# Epoch 56/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5157 - val_loss: 0.6047
# Epoch 57/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5118 - val_loss: 0.6017
# Epoch 58/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5107 - val_loss: 0.6047
# Epoch 59/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5095 - val_loss: 0.5954
# Epoch 60/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5038 - val_loss: 0.6060
# Epoch 61/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5051 - val_loss: 0.6090
# Epoch 62/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5012 - val_loss: 0.6076
# Epoch 63/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4973 - val_loss: 0.6074
# Epoch 64/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5081 - val_loss: 0.6203
# Epoch 65/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5071 - val_loss: 0.6022
# Epoch 66/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4895 - val_loss: 0.6228
# Epoch 67/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.5001 - val_loss: 0.6082
# Epoch 68/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.5025 - val_loss: 0.6145
# Epoch 69/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4888 - val_loss: 0.6239
# Epoch 70/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4873 - val_loss: 0.6108
# Epoch 71/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4932 - val_loss: 0.6180
# Epoch 72/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.4945 - val_loss: 0.6105
# Epoch 73/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4880 - val_loss: 0.6184
# Epoch 74/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4895 - val_loss: 0.6101
# Epoch 75/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4833 - val_loss: 0.6145
# Epoch 76/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4826 - val_loss: 0.6108
# Epoch 77/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4873 - val_loss: 0.6060
# Epoch 78/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4823 - val_loss: 0.6105
# Epoch 79/100
# 82/82 [==============================] - 1s 11ms/step - loss: 0.4794 - val_loss: 0.6187
# Epoch 80/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.4747 - val_loss: 0.6110
# Epoch 81/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.4819 - val_loss: 0.6042
# Epoch 82/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4785 - val_loss: 0.6236
# Epoch 83/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4840 - val_loss: 0.6044
# Epoch 84/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4708 - val_loss: 0.6210
# Epoch 85/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4700 - val_loss: 0.6169
# Epoch 86/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.4691 - val_loss: 0.6147
# Epoch 87/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4593 - val_loss: 0.6383
# Epoch 88/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.4697 - val_loss: 0.6269
# Epoch 89/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4674 - val_loss: 0.6180
# Epoch 90/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4617 - val_loss: 0.6195
# Epoch 91/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4690 - val_loss: 0.6095
# Epoch 92/100
# 82/82 [==============================] - 1s 7ms/step - loss: 0.4684 - val_loss: 0.6154
# Epoch 93/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4702 - val_loss: 0.6243
# Epoch 94/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4586 - val_loss: 0.6211
# Epoch 95/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4641 - val_loss: 0.6220
# Epoch 96/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4549 - val_loss: 0.6342
# Epoch 97/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4619 - val_loss: 0.6280
# Epoch 98/100
# 82/82 [==============================] - 0s 5ms/step - loss: 0.4562 - val_loss: 0.6460
# Epoch 99/100
# 82/82 [==============================] - 1s 6ms/step - loss: 0.4442 - val_loss: 0.6347
# Epoch 100/100
# 82/82 [==============================] - 0s 6ms/step - loss: 0.4459 - val_loss: 0.6363
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f4046ab79e0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(X_test)
y_pred = [ 1 if y>=0.5 else 0 for y in y_pred ]

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       412
#            1       0.37      1.00      0.54       244
#
#     accuracy                           0.37       656
#    macro avg       0.19      0.50      0.27       656
# weighted avg       0.14      0.37      0.20       656
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")
# Out:
# [[  0 412]
#  [  0 244]]
# Accuracy: 37.19512195121951%
